# %%
from sklearn.cross_validation import train_test_split
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn import datasets, neighbors, linear_model
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import MySQLdb
import json
import itertools
import os
# %matplotlib inline

# %%
def roc_curve(probabilities, labels):
    '''
    INPUT: numpy array, numpy array
    OUTPUT: list, list, list
    Take a numpy array of the predicted probabilities and a numpy array of the
    true labels.
    Return the True Positive Rates, False Positive Rates and Thresholds for the
    ROC curve.
    '''
    
    thresholds = np.sort(probabilities)

    tprs = []
    fprs = []

    num_positive_cases = sum(labels)
    num_negative_cases = len(labels) - num_positive_cases

    for threshold in thresholds:
        # With this threshold, give the prediction of each instance
        predicted_positive = probabilities >= threshold
        # Calculate the number of correctly predicted positive cases
        true_positives = np.sum(predicted_positive * labels)
        # Calculate the number of incorrectly predicted positive cases
        false_positives = np.sum(predicted_positive) - true_positives
        # Calculate the True Positive Rate
        tpr = true_positives / float(num_positive_cases)
        # Calculate the False Positive Rate
        fpr = false_positives / float(num_negative_cases)

        fprs.append(fpr)
        tprs.append(tpr)

    return tprs, fprs, thresholds.tolist()

# %%
# Get MySQLdb password
passwd_path = '/Users/deck/_galvanize/_project/sportradar/api_keys/mysql.json'
with open(passwd_path) as f:
    data = json.load(f)
    passwd = data['access-key']
    
    
# Establish connection to MySQL database
conn = MySQLdb.connect(host="localhost",
                       user="root",
                       passwd=passwd,
                       db="hockey")
cur = conn.cursor()

# %%
sql = 'SELECT * FROM temp;'
df = pd.read_sql(sql, conn)
y = df.pop('win').values
X = df.values
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
def fit_models(X_train, X_test, y_train, y_test):

#     model = LogisticRegression()
#     model.fit(X_train, y_train)
#     y_hats = model.predict(X_test)
    knn = neighbors.KNeighborsClassifier()
    logistic = linear_model.LogisticRegression()
    gb = GradientBoostingClassifier()
    rf = RandomForestClassifier()
    svm = SVC(kernel='linear')
    
    knn_score = knn.fit(X_train, y_train).score(X_test, y_test)
    logistic_score = logistic.fit(X_train, y_train).score(X_test, y_test)
    gb_score = gb.fit(X_train, y_train).score(X_test, y_test)
    rf_score = rf.fit(X_train, y_train).score(X_test, y_test)
    svm_score = svm.fit(X_train, y_train).score(X_test, y_test)
    
    
    print('KNN score: %f') % knn_score
    print('LogisticRegression score: %f') % logistic_score
    print('LinearRegression score: %f') % linear_score
    print('Gradient Boosting score: %f') % gb_score
    print('RandomForest score: %f') % rf_score
    print('SVM score: %f') % svm_score

# %%
fit_models(X_train, X_test, y_train, y_test)
# Out:
# KNN score: 0.590909
# LogisticRegression score: 0.853896
# LinearRegression score: 0.531961
# Gradient Boosting score: 0.857143
# RandomForest score: 0.805195
# SVM score: 0.860390

# %%
pd.scatter_matrix(df, figsize=(20,20))
plt.show()
